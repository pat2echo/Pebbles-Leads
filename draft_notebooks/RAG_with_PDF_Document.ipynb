# %% [markdown]
# # Install Ollama in Colab

# %%
# enable support for gpu
# !apt-get install lshw

# download ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# start ollama in background to orevent blocking the terminal
# !nohup ollama serve &

# run ollama with llama2 model
# !ollama run llama2

# or run ollama with mistral model
# !ollama run mistral
# Out:
# ^C

# %% [markdown]
# ### Import libraries

# %%
# !pip install langchain_community
# !pip install pypdf
# !pip install fastembed
# !pip install chromadb
# Out:
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.11/dist-packages (0.3.23)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.56 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.56)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.24)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.39)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.24->langchain_community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.24->langchain_community) (2.11.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.56->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.56->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.56->langchain_community) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.56->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain_community) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.11/dist-packages (5.4.0)
# Requirement already satisfied: fastembed in /usr/local/lib/python3.11/dist-packages (0.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in /usr/local/lib/python3.11/dist-packages (from fastembed) (0.30.2)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from fastembed) (0.7.3)
# Requirement already satisfied: mmh3<6.0.0,>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from fastembed) (5.1.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from fastembed) (2.0.2)
# Requirement already satisfied: onnxruntime!=1.20.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from fastembed) (1.22.0)
# Requirement already satisfied: pillow<12.0.0,>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from fastembed) (11.2.1)
# Requirement already satisfied: py-rust-stemmers<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from fastembed) (0.1.5)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.11/dist-packages (from fastembed) (2.32.3)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from fastembed) (0.21.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /usr/local/lib/python3.11/dist-packages (from fastembed) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed) (4.13.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->fastembed) (2025.4.26)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.3.0)

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.chat_models import ChatOllama
from langchain_community.embeddings.fastembed import FastEmbedEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
import sys

# %% [markdown]
# ### Split the doucment into Chunks & Store them in Vector Store

# %%
def ingest():
    # Get the doc
    loader = PyPDFLoader("/content/sample_data/SQL Server 2012 T-SQL Recipes.pdf")
    pages = loader.load_and_split()
    # Split the pages by char
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1024,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )
    chunks = text_splitter.split_documents(pages)
    print(f"Split {len(pages)} documents into {len(chunks)} chunks.")
    #
    embedding = FastEmbedEmbeddings()
    #Create vector store
    Chroma.from_documents(documents=chunks,  embedding=embedding, persist_directory="./sql_chroma_db")

# %%
# only run this once to generate vector store
ingest()
# Out:
# Split 23 documents into 47 chunks.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from huggingface_hub import login
login(token = access_token_read)

# %% [markdown]
# ### Create a RAG chain that retreives relevent chunks and prepares a response

# %%
def rag_chain():
    model = ChatOllama(model="llama3")
    #
    prompt = PromptTemplate.from_template(
        """
        <s> [Instructions] You are a friendly assistant. Answer the question based only on the following context.
        If you don't know the answer, then reply, No Context availabel for this question {input}. [/Instructions] </s>
        [Instructions] Question: {input}
        Context: {context}
        Answer: [/Instructions]
        """
    )
    #Load vector store
    embedding = FastEmbedEmbeddings()
    vector_store = Chroma(persist_directory="./sql_chroma_db", embedding_function=embedding)

    #Create chain
    retriever = vector_store.as_retriever(
        search_type="similarity_score_threshold",
        search_kwargs={
            "k": 3,
            "score_threshold": 0.5,
        },
    )

    document_chain = create_stuff_documents_chain(model, prompt)
    chain = create_retrieval_chain(retriever, document_chain)
    #
    return chain

# %%
print("Test")

# %%
print("Test")

# %%
def ask(query: str):
    #
    chain = rag_chain()
    # invoke chain
    result = chain.invoke({"input": query})
    # print results
    print(result["answer"])
    for doc in result["context"]:
        print("Source: ", doc.metadata["source"])

# %% [markdown]
# # Extract Documents

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

# Base URL of the list of papers
base_url = 'https://arxiv.org/list/astro-ph/2025-01?skip={}&show=100'

# Folder where PDFs will be saved
output_folder = '/content/arxiv_pdfs'

# Function to create a folder if it doesn't exist
def create_folder(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

# Function to download a single PDF
def download_pdf(pdf_url, output_folder):
    # Construct the full URL
    full_url = urljoin('https://arxiv.org', pdf_url)
    pdf_name = pdf_url.split('/')[-1] + '.pdf'
    pdf_path = os.path.join(output_folder, pdf_name)

    # Download and save the PDF
    print(f"Downloading: {pdf_name}")
    response = requests.get(full_url)
    with open(pdf_path, 'wb') as f:
        f.write(response.content)

    print(f"Saved: {pdf_name}")

# Function to scrape PDFs from a single page
def scrape_pdfs(page_url, output_folder):
    print(f"Scraping: {page_url}")

    # Fetch the page content
    response = requests.get(page_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all links to PDFs
    pdf_links = soup.find_all('a', {'title': 'Download PDF'})

    # Download all PDFs
    for link in pdf_links:
        pdf_url = link.get('href')
        download_pdf(pdf_url, output_folder)

# Main scraping loop
def scrape_arxiv_pdfs(start_page=0, end_page=1000, output_folder=output_folder):
    create_folder(output_folder)  # Ensure the output folder exists

    # Loop through pages
    for skip in range(start_page, end_page, 100):
        page_url = base_url.format(skip)
        scrape_pdfs(page_url, output_folder)

        # Wait before scraping the next page to avoid server overload
        time.sleep(3)

# Start the scraping process
scrape_arxiv_pdfs(start_page=0, end_page=500, output_folder=output_folder)

# %%
# !zip -r /content/arxiv_pdfs.zip /content/arxiv_pdfs/
# Out:
#   adding: content/arxiv_pdfs/ (stored 0%)
#   adding: content/arxiv_pdfs/2501.04834.pdf (deflated 28%)
#   adding: content/arxiv_pdfs/2501.04768.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.04737.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.06950.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.05883.pdf (deflated 21%)
#   adding: content/arxiv_pdfs/2501.03082.pdf (deflated 20%)
#   adding: content/arxiv_pdfs/2501.06453.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.04095.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.06297.pdf (deflated 23%)
#   adding: content/arxiv_pdfs/2501.06498.pdf (deflated 26%)
#   adding: content/arxiv_pdfs/2501.05187.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.05393.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.03791.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.06982.pdf (deflated 23%)
#   adding: content/arxiv_pdfs/2501.00544.pdf (deflated 1%)
#   adding: content/arxiv_pdfs/2501.05114.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.02096.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.05042.pdf (deflated 18%)
#   adding: content/arxiv_pdfs/2501.07188.pdf (deflated 23%)
#   adding: content/arxiv_pdfs/2501.05569.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.02720.pdf (deflated 21%)
#   adding: content/arxiv_pdfs/2501.03827.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.02206.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.03876.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.05139.pdf (deflated 15%)
#   adding: content/arxiv_pdfs/2501.00380.pdf (deflated 11%)
#   adding: content/arxiv_pdfs/2501.06358.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.05152.pdf (deflated 10%)
#   adding: content/arxiv_pdfs/2501.04943.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.03094.pdf (deflated 11%)
#   adding: content/arxiv_pdfs/2501.04800.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.01940.pdf (deflated 14%)
#   adding: content/arxiv_pdfs/2501.05521.pdf (deflated 33%)
#   adding: content/arxiv_pdfs/2501.00228.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.06734.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.06149.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.03803.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.02108.pdf (deflated 24%)
#   adding: content/arxiv_pdfs/2501.02050.pdf (deflated 16%)
#   adding: content/arxiv_pdfs/2501.03723.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.05993.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.07160.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.00676.pdf (deflated 3%)
#   adding: content/arxiv_pdfs/2501.02272.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.07151.pdf (deflated 3%)
#   adding: content/arxiv_pdfs/2501.03315.pdf (deflated 11%)
#   adding: content/arxiv_pdfs/2501.07049.pdf (deflated 15%)
#   adding: content/arxiv_pdfs/2501.04912.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.00979.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.01698.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.04084.pdf (deflated 16%)
#   adding: content/arxiv_pdfs/2501.06664.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.00239.pdf (deflated 34%)
#   adding: content/arxiv_pdfs/2501.01879.pdf (deflated 3%)
#   adding: content/arxiv_pdfs/2501.03065.pdf (deflated 29%)
#   adding: content/arxiv_pdfs/2501.06056.pdf (deflated 18%)
#   adding: content/arxiv_pdfs/2501.02054.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.02473.pdf (deflated 2%)
#   adding: content/arxiv_pdfs/2501.05514.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.04075.pdf (deflated 25%)
#   adding: content/arxiv_pdfs/2501.06891.pdf (deflated 16%)
#   adding: content/arxiv_pdfs/2501.00986.pdf (deflated 23%)
#   adding: content/arxiv_pdfs/2501.04748.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.06712.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.03361.pdf (deflated 2%)
#   adding: content/arxiv_pdfs/2501.05518.pdf (deflated 29%)
#   adding: content/arxiv_pdfs/2501.02864.pdf (deflated 11%)
#   adding: content/arxiv_pdfs/2501.05023.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.07001.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.05739.pdf (deflated 14%)
#   adding: content/arxiv_pdfs/2501.02731.pdf (deflated 19%)
#   adding: content/arxiv_pdfs/2501.00294.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.06462.pdf (deflated 18%)
#   adding: content/arxiv_pdfs/2501.00181.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.00255.pdf (deflated 11%)
#   adding: content/arxiv_pdfs/2501.01528.pdf (deflated 2%)
#   adding: content/arxiv_pdfs/2501.04020.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.00796.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.03614.pdf (deflated 30%)
#   adding: content/arxiv_pdfs/2501.03716.pdf (deflated 42%)
#   adding: content/arxiv_pdfs/2501.07099.pdf (deflated 21%)
#   adding: content/arxiv_pdfs/2501.07119.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.04096.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501
pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.02835.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.04906.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.02051.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.03678.pdf (deflated 10%)
#   adding: content/arxiv_pdfs/2501.01530.pdf (deflated 23%)
#   adding: content/arxiv_pdfs/2501.07082.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.05424.pdf (deflated 16%)
#   adding: content/arxiv_pdfs/2501.03633.pdf (deflated 19%)
#   adding: content/arxiv_pdfs/2501.06611.pdf (deflated 26%)
#   adding: content/arxiv_pdfs/2501.04247.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.02225.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.01495.pdf (deflated 31%)
#   adding: content/arxiv_pdfs/2501.05740.pdf (deflated 15%)
#   adding: content/arxiv_pdfs/2501.02204.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.04081.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.00769.pdf (deflated 31%)
#   adding: content/arxiv_pdfs/2501.03656.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.06333.pdf (deflated 2%)
#   adding: content/arxiv_pdfs/2501.02587.pdf (deflated 16%)
#   adding: content/arxiv_pdfs/2501.01490.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.03323.pdf (deflated 8%)
#   adding: content/arxiv_pdfs/2501.03178.pdf (deflated 11%)
#   adding: content/arxiv_pdfs/2501.01532.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.05086.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.02664.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.05916.pdf (deflated 3%)
#   adding: content/arxiv_pdfs/2501.06342.pdf (deflated 16%)
#   adding: content/arxiv_pdfs/2501.02923.pdf (deflated 7%)
#   adding: content/arxiv_pdfs/2501.06532.pdf (deflated 14%)
#   adding: content/arxiv_pdfs/2501.06379.pdf (deflated 21%)
#   adding: content/arxiv_pdfs/2501.06301.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.01387.pdf (deflated 24%)
#   adding: content/arxiv_pdfs/2501.06295.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.03513.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.01009.pdf (deflated 2%)
#   adding: content/arxiv_pdfs/2501.05571.pdf (deflated 20%)
#   adding: content/arxiv_pdfs/2501.01613.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.06169.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.00176.pdf (deflated 31%)
#   adding: content/arxiv_pdfs/2501.05531.pdf (deflated 24%)
#   adding: content/arxiv_pdfs/2501.03831.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.05602.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.03520.pdf (deflated 14%)
#   adding: content/arxiv_pdfs/2501.02907.pdf (deflated 26%)
#   adding: content/arxiv_pdfs/2501.05297.pdf (deflated 10%)
#   adding: content/arxiv_pdfs/2501.04090.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.04925.pdf (deflated 10%)
#   adding: content/arxiv_pdfs/2501.07225.pdf (deflated 22%)
#   adding: content/arxiv_pdfs/2501.01331.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.02076.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.03685.pdf (deflated 15%)
#   adding: content/arxiv_pdfs/2501.06140.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.05632.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.05506.pdf (deflated 15%)
#   adding: content/arxiv_pdfs/2501.06185.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.02103.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.01946.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.06961.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.01857.pdf (deflated 32%)
#   adding: content/arxiv_pdfs/2501.04968.pdf (deflated 24%)
#   adding: content/arxiv_pdfs/2501.03433.pdf (deflated 27%)
#   adding: content/arxiv_pdfs/2501.03920.pdf (deflated 37%)
#   adding: content/arxiv_pdfs/2501.02329.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.02959.pdf (deflated 10%)
#   adding: content/arxiv_pdfs/2501.04077.pdf (deflated 10%)
#   adding: content/arxiv_pdfs/2501.00431.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.04960.pdf (deflated 21%)
#   adding: content/arxiv_pdfs/2501.03217.pdf (deflated 27%)
#   adding: content/arxiv_pdfs/2501.06156.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.06290.pdf (deflated 22%)
#   adding: content/arxiv_pdfs/2501.02592.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.03330.pdf (deflated 19%)
#   adding: content/arxiv_pdfs/2501.07189.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.01578.pdf (deflated 10%)
#   adding: content/arxiv_pdfs/2501.03506.pdf (deflated 19%)
#   adding: content/arxiv_pdfs/2501.03100.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.06303.pdf (deflated 4%)
#   adding: content/arxiv_pdfs/2501.04788.pdf (deflated 23%)
#   adding: content/arxiv_pdfs/2501.03796.pdf (deflated 6%)
#   adding: content/arxiv_pdfs/2501.04080.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.00373.pdf (deflated 33%)
#   adding: content/arxiv_pdfs/2501.02317.pdf (deflated 7%)
#   adding: content/arxiv_pdfs/2501.02163.pdf (deflated 12%)
#   adding: content/arxiv_pdfs/2501.03322.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.03328.pdf (deflated 19%)
#   adding: content/arxiv_pdfs/2501.05692.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.03756.pdf (deflated 17%)
#   adding: content/arxiv_pdfs/2501.04171.pdf (deflated 9%)
#   adding: content/arxiv_pdfs/2501.05781.pdf (deflated 7%)
#   adding: content/arxiv_pdfs/2501.05110.pdf (deflated 3%)
#   adding: content/arxiv_pdfs/2501.03133.pdf (deflated 13%)
#   adding: content/arxiv_pdfs/2501.06011.pdf (deflated 20%)
#   adding: content/arxiv_pdfs/2501.06378.pdf (deflated 5%)
#   adding: content/arxiv_pdfs/2501.02645.pdf (deflated 4%)
